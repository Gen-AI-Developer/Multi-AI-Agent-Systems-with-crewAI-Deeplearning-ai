# %% [markdown]
# # L2: Create Agents to Research and Write an Article
#
# In this lesson, you will be introduced to the foundational concepts of multi-agent systems and get an overview of the crewAI framework.

# %% [markdown]
# The libraries are already installed in the classroom. If you're running this notebook on your own machine, you can install the following:
# ```Python
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29
# ```

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ```Python
# %pip install crewai crewai_tools langchain_community
# ```

# %%
# %pip install crewai crewai-tools
# Out:
# Collecting crewai
#   Using cached crewai-0.86.0-py3-none-any.whl.metadata (19 kB)
# Collecting crewai-tools
#   Using cached crewai_tools-0.17.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting appdirs>=1.4.4 (from crewai)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting auth0-python>=4.7.1 (from crewai)
#   Using cached auth0_python-4.7.2-py3-none-any.whl.metadata (8.9 kB)
# Collecting chromadb>=0.5.18 (from crewai)
#   Using cached chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting click>=8.1.7 (from crewai)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting instructor>=1.3.3 (from crewai)
#   Using cached instructor-1.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting json-repair>=0.25.2 (from crewai)
#   Using cached json_repair-0.32.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Using cached jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm>=1.44.22 (from crewai)
#   Using cached litellm-1.55.7-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openai>=1.13.3 in c:\python312\lib\site-packages (from crewai) (1.57.4)
# Collecting openpyxl>=3.1.5 (from crewai)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-api>=1.22.0 (from crewai)
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.22.0 (from crewai)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk>=1.22.0 (from crewai)
#   Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Using cached pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: pydantic>=2.4.2 in c:\python312\lib\site-packages (from crewai) (2.10.3)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\python312\lib\site-packages (from crewai) (1.0.1)
# Collecting pyvis>=0.3.2 (from crewai)
#   Using cached pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting regex>=2024.9.11 (from crewai)
#   Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Using cached tomli_w-1.1.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Using cached tomli-2.2.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Using cached uv-0.5.11-py3-none-win_amd64.whl.metadata (11 kB)
# Collecting beautifulsoup4>=4.12.3 (from crewai-tools)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting docker>=7.1.0 (from crewai-tools)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting docx2txt>=0.8 (from crewai-tools)
#   Using cached docx2txt-0.8-py3-none-any.whl
# Collecting embedchain>=0.1.114 (from crewai-tools)
#   Using cached embedchain-0.1.125-py3-none-any.whl.metadata (9.3 kB)
# Collecting lancedb>=0.5.4 (from crewai-tools)
#   Using cached lancedb-0.17.0-cp39-abi3-win_amd64.whl.metadata (4.8 kB)
# Collecting pyright>=1.1.350 (from crewai-tools)
#   Using cached pyright-1.1.391-py3-none-any.whl.metadata (6.7 kB)
# Collecting pytest>=8.0.0 (from crewai-tools)
#   Using cached pytest-8.3.4-py3-none-any.whl.metadata (7.5 kB)
# Collecting pytube>=15.0.0 (from crewai-tools)
#   Using cached pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: requests>=2.31.0 in c:\python312\lib\site-packages (from crewai-tools) (2.32.3)
# Collecting selenium>=4.18.1 (from crewai-tools)
#   Using cached selenium-4.27.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.5 in c:\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (3.11.10)
# Collecting cryptography<44.0.0,>=43.0.1 (from auth0-python>=4.7.1->crewai)
#   Using cached cryptography-43.0.3-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting pyjwt<3.0.0,>=2.8.0 (from auth0-python>=4.7.1->crewai)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in c:\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.2.3)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.12.3->crewai-tools)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting build>=1.0.3 (from chromadb>=0.5.18->crewai)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.5.18->crewai)
#   Using cached chroma_hnswlib-0.7.6-cp312-cp312-win_amd64.whl
# Collecting fastapi>=0.95.2 (from chromadb>=0.5.18->crewai)
#   Using cached fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (2.2.0)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.18->crewai)
#   Using cached posthog-3.7.4-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.5.18->crewai)
#   Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.18->crewai)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.5.18->crewai)
#   Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting tokenizers<=0.20.3,>=0.13.2 (from chromadb>=0.5.18->crewai)
#   Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.18->crewai)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.18->crewai)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb>=0.5.18->crewai)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (1.68.1)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.18->crewai)
#   Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb>=0.5.18->crewai)
#   Using cached typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.18->crewai)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.18->crewai)
#   Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb>=0.5.18->crewai)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from click>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: pywin32>=304 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from docker>=7.1.0->crewai-tools) (308)
# Collecting alembic<2.0.0,>=1.13.1 (from embedchain>=0.1.114->crewai-tools)
#   Using cached alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting cohere<6.0,>=5.3 (from embedchain>=0.1.114->crewai-tools)
#   Using cached cohere-5.13.4-py3-none-any.whl.metadata (3.4 kB)
# Collecting google-cloud-aiplatform<2.0.0,>=1.26.1 (from embedchain>=0.1.114->crewai-tools)
#   Using cached google_cloud_aiplatform-1.75.0-py2.py3-none-any.whl.metadata (31 kB)
# Collecting gptcache<0.2.0,>=0.1.43 (from embedchain>=0.1.114->crewai-tools)
#   Using cached gptcache-0.1.44-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.12)
# Collecting langchain-cohere<0.4.0,>=0.3.0 (from embedchain>=0.1.114->crewai-tools)
#   Using cached langchain_cohere-0.3.4-py3-none-any.whl.metadata (6.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools)
#   Using cached langchain_community-0.3.13-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-openai<0.3.0,>=0.2.1 (from embedchain>=0.1.114->crewai-tools)
#   Using cached langchain_openai-0.2.14-py3-none-any.whl.metadata (2.7 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from embedchain>=0.1.114->crewai-tools)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting mem0ai<0.2.0,>=0.1.29 (from embedchain>=0.1.114->crewai-tools)
#   Using cached mem0ai-0.1.36-py3-none-any.whl.metadata (10 kB)
# Collecting pypdf<6.0.0,>=5.0.0 (from embedchain>=0.1.114->crewai-tools)
#   Using cached pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pysbd<0.4.0,>=0.3.4 (from embedchain>=0.1.114->crewai-tools)
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting schema<0.8.0,>=0.7.5 (from embedchain>=0.1.114->crewai-tools)
#   Using cached schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (2.0.36)
# Collecting tiktoken<0.8.0,>=0.7.0 (from embedchain>=0.1.114->crewai-tools)
#   Using cached tiktoken-0.7.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting docstring-parser<0.17,>=0.16 (from instructor>=1.3.3->crewai)
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting jinja2<4.0.0,>=3.1.4 (from instructor>=1.3.3->crewai)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jiter<0.7,>=0.6.1 (from instructor>=1.3.3->crewai)
#   Using cached jiter-0.6.1-cp312-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\python312\lib\site-packages (from instructor>=1.3.3->crewai) (2.27.1)
# Collecting deprecation (from lancedb>=0.5.4->crewai-tools)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pylance==0.20.0 (from lancedb>=0.5.4->crewai-tools)
#   Using cached pylance-0.20.0-cp39-abi3-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: packaging in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from lancedb>=0.5.4->crewai-tools) (24.2)
# Collecting pyarrow>=14 (from pylance==0.20.0->lancedb>=0.5.4->crewai-tools)
#   Using cached pyarrow-18.1.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting httpx>=0.27.0 (from chromadb>=0.5.18->crewai)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting importlib-metadata>=6.8.0 (from litellm>=1.44.22->crewai)
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting jsonschema<5.0.0,>=4.22.0 (from litellm>=1.44.22->crewai)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\python312\lib\site-packages (from openai>=1.13.3->crewai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\python312\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in c:\python312\lib\site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Collecting et-xmlfile (from openpyxl>=3.1.5->crewai)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.22.0->crewai)
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.29.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Using cached opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\python312\lib\site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.29.1)
# Collecting opentelemetry-semantic-conventions==0.50b0 (from opentelemetry-sdk>=1.22.0->crewai)
#   Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber>=0.11.4->crewai)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting Pillow>=9.1 (from pdfplumber>=0.11.4->crewai)
#   Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python312\lib\site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Collecting nodeenv>=1.6.0 (from pyright>=1.1.350->crewai-tools)
#   Using cached nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting iniconfig (from pytest>=8.0.0->crewai-tools)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2,>=1.5 (from pytest>=8.0.0->crewai-tools)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from pyvis>=0.3.2->crewai) (8.30.0)
# Collecting jsonpickle>=1.4.1 (from pyvis>=0.3.2->crewai)
#   Using cached jsonpickle-4.0.1-py3-none-any.whl.metadata (8.2 kB)
# Collecting networkx>=1.11 (from pyvis>=0.3.2->crewai)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests>=2.31.0->crewai-tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests>=2.31.0->crewai-tools) (2024.12.14)
# Collecting trio~=0.17 (from selenium>=4.18.1->crewai-tools)
#   Using cached trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium>=4.18.1->crewai-tools)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client~=1.8 (from selenium>=4.18.1->crewai-tools)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.18.3)
# Collecting Mako (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools)
#   Using cached Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb>=0.5.18->crewai)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools)
#   Using cached fastavro-1.10.0-cp312-cp312-win_amd64.whl.metadata (5.7 kB)
# Collecting httpx-sse==0.4.0 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools)
#   Using cached parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools)
#   Using cached types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Collecting cffi>=1.12 (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai)
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai)
#   Using cached wrapt-1.17.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb>=0.5.18->crewai)
#   Using cached starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.24.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.37.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.25.0)
# Collecting google-cloud-storage<3.0.0dev,>=1.32.0 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached google_cloud_storage-2.19.0-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached google_cloud_bigquery-3.27.0-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached google_cloud_resource_manager-1.14.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting shapely<3.0.0dev (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: cachetools in c:\python312\lib\site-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools) (5.5.0)
# Requirement already satisfied: httpcore==1.* in c:\python312\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.18->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.18->crewai) (0.14.0)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai)
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: decorator in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai)
#   Using cached rpds_py-0.22.3-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (2.9.0.post0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in c:\python312\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.25)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\python312\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.3)
# Collecting langchain-core<0.4.0,>=0.3.25 (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Using cached langchain_core-0.3.28-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-experimental<0.4.0,>=0.3.0 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Using cached langchain_experimental-0.3.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting pandas>=1.4.3 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting tabulate<0.10.0,>=0.9.0 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools)
#   Using cached langchain-0.3.13-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Using cached pydantic_settings-2.7.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting openai>=1.13.3 (from crewai)
#   Using cached openai-1.58.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Collecting pytz<2025.0,>=2024.1 (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting qdrant-client<2.0.0,>=1.9.1 (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached qdrant_client-1.12.1-py3-none-any.whl.metadata (10 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai)
#   Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai)
#   Using cached opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai)
#   Using cached opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.5.18->crewai)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.5.18->crewai)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb>=0.5.18->crewai)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python312\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools) (3.1.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai)
#   Using cached huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting sortedcontainers (from trio~=0.17->selenium>=4.18.1->crewai-tools)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium>=4.18.1->crewai-tools)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium>=4.18.1->crewai-tools)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb>=0.5.18->crewai)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai-tools)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai)
#   Using cached watchfiles-1.0.3-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai)
#   Using cached websockets-14.1-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting pycparser (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Using cached marshmallow-3.23.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.68.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (4.9)
# Collecting google-cloud-core<3.0.0dev,>=2.4.1 (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0dev,>=2.0.0 (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4 (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached grpc_google_iam_v1-0.13.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools)
#   Using cached google_crc32c-1.6.0-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.33)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.18->crewai)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: wcwidth in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached grpcio_tools-1.68.1-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting setuptools (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.6.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools)
#   Using cached hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Using cached crewai-0.86.0-py3-none-any.whl (192 kB)
# Using cached crewai_tools-0.17.0-py3-none-any.whl (467 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached auth0_python-4.7.2-py3-none-any.whl (131 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached chromadb-0.5.23-py3-none-any.whl (628 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached embedchain-0.1.125-py3-none-any.whl (211 kB)
# Using cached instructor-1.7.0-py3-none-any.whl (70 kB)
# Using cached json_repair-0.32.0-py3-none-any.whl (19 kB)
# Using cached jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Using cached lancedb-0.17.0-cp39-abi3-win_amd64.whl (27.5 MB)
# Using cached pylance-0.20.0-cp39-abi3-win_amd64.whl (31.4 MB)
# Using cached litellm-1.55.7-py3-none-any.whl (6.5 MB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
# Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
# Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
# Using cached pdfplumber-0.11.4-py3-none-any.whl (59 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached pyright-1.1.391-py3-none-any.whl (18 kB)
# Using cached pytest-8.3.4-py3-none-any.whl (343 kB)
# Using cached pytube-15.0.0-py3-none-any.whl (57 kB)
# Using cached pyvis-0.3.2-py3-none-any.whl (756 kB)
# Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Using cached selenium-4.27.1-py3-none-any.whl (9.7 MB)
# Using cached tomli-2.2.1-cp312-cp312-win_amd64.whl (109 kB)
# Using cached tomli_w-1.1.0-py3-none-any.whl (6.4 kB)
# Using cached uv-0.5.11-py3-none-win_amd64.whl (16.2 MB)
# Using cached alembic-1.14.0-py3-none-any.whl (233 kB)
# Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl (153 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached cohere-5.13.4-py3-none-any.whl (250 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Using cached cryptography-43.0.3-cp39-abi3-win_amd64.whl (3.1 MB)
# Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Using cached fastapi-0.115.6-py3-none-any.whl (94 kB)
# Using cached google_cloud_aiplatform-1.75.0-py2.py3-none-any.whl (6.9 MB)
# Using cached gptcache-0.1.44-py3-none-any.whl (131 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jiter-0.6.1-cp312-none-win_amd64.whl (198 kB)
# Using cached jsonpickle-4.0.1-py3-none-any.whl (46 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Using cached langchain_cohere-0.3.4-py3-none-any.whl (44 kB)
# Using cached langchain_community-0.3.13-py3-none-any.whl (2.5 MB)
# Using cached langchain-0.3.13-py3-none-any.whl (1.0 MB)
# Using cached langchain_openai-0.2.14-py3-none-any.whl (50 kB)
# Using cached openai-1.58.1-py3-none-any.whl (454 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached mem0ai-0.1.36-py3-none-any.whl (83 kB)
# Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl (39 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached posthog-3.7.4-py2.py3-none-any.whl (54 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached pypdf-5.1.0-py3-none-any.whl (297 kB)
# Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
# Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached tiktoken-0.7.0-cp312-cp312-win_amd64.whl (799 kB)
# Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl (2.4 MB)
# Using cached trio-0.27.0-py3-none-any.whl (481 kB)
# Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached typer-0.15.1-py3-none-any.whl (44 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached fastavro-1.10.0-cp312-cp312-win_amd64.whl (487 kB)
# Using cached google_cloud_bigquery-3.27.0-py2.py3-none-any.whl (240 kB)
# Using cached google_cloud_resource_manager-1.14.0-py2.py3-none-any.whl (384 kB)
# Using cached google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached langchain_core-0.3.28-py3-none-any.whl (411 kB)
# Using cached langchain_experimental-0.3.3-py3-none-any.whl (208 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Using cached pyarrow-18.1.0-cp312-cp312-win_amd64.whl (25.1 MB)
# Using cached pydantic_settings-2.7.0-py3-none-any.whl (29 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached qdrant_client-1.12.1-py3-none-any.whl (267 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.22.3-cp312-cp312-win_amd64.whl (235 kB)
# Using cached shapely-2.0.6-cp312-cp312-win_amd64.whl (1.4 MB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.41.3-py3-none-any.whl (73 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Using cached watchfiles-1.0.3-cp312-cp312-win_amd64.whl (285 kB)
# Using cached websockets-14.1-cp312-cp312-win_amd64.whl (163 kB)
# Using cached wrapt-1.17.0-cp312-cp312-win_amd64.whl (38 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached Mako-1.3.8-py3-none-any.whl (78 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Using cached google_crc32c-1.6.0-cp312-cp312-win_amd64.whl (33 kB)
# Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Using cached grpc_google_iam_v1-0.13.1-py2.py3-none-any.whl (24 kB)
# Using cached grpcio_tools-1.68.1-cp312-cp312-win_amd64.whl (1.1 MB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached marshmallow-3.23.2-py3-none-any.whl (49 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached portalocker-2.10.1-py3-none-any.whl (18 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached h2-4.1.0-py3-none-any.whl (57 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Using cached setuptools-75.6.0-py3-none-any.whl (1.2 MB)
# Using cached hpack-4.0.0-py3-none-any.whl (32 kB)
# Using cached hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: sortedcontainers, schema, pytz, pypika, mpmath, monotonic, flatbuffers, durationpy, docx2txt, appdirs, zipp, wsproto, wrapt, websockets, websocket-client, uv, tzdata, types-requests, tomli-w, tomli, tabulate, sympy, soupsieve, shellingham, shapely, setuptools, rpds-py, regex, pytube, pysocks, pysbd, pyreadline3, pyproject_hooks, pypdfium2, pypdf, pyjwt, pycparser, pyarrow, portalocker, pluggy, Pillow, parameterized, overrides, outcome, opentelemetry-util-http, opentelemetry-proto, oauthlib, nodeenv, networkx, mypy-extensions, mmh3, mdurl, marshmallow, MarkupSafe, jsonref, jsonpickle, json-repair, jiter, iniconfig, importlib-resources, hyperframe, httpx-sse, httptools, hpack, google-crc32c, fsspec, filelock, fastavro, et-xmlfile, docstring-parser, deprecation, click, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, requests-oauthlib, referencing, pytest, pyright, pylance, posthog, pandas, opentelemetry-exporter-otlp-proto-common, openpyxl, markdown-it-py, Mako, jinja2, importlib-metadata, humanfriendly, huggingface-hub, httpx, h2, grpcio-tools, gptcache, google-resumable-media, docker, deprecated, cffi, build, beautifulsoup4, trio, tokenizers, rich, pyvis, pydantic-settings, opentelemetry-api, openai, langsmith, lancedb, kubernetes, jsonschema-specifications, grpc-google-iam-v1, fastapi, dataclasses-json, cryptography, coloredlogs, alembic, typer, trio-websocket, qdrant-client, pdfminer.six, opentelemetry-semantic-conventions, onnxruntime, langchain-core, jsonschema, google-cloud-core, cohere, auth0-python, selenium, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, mem0ai, litellm, langchain-openai, instructor, google-cloud-storage, google-cloud-resource-manager, google-cloud-bigquery, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, langchain, google-cloud-aiplatform, opentelemetry-instrumentation-fastapi, langchain-community, langchain-experimental, chromadb, langchain-cohere, embedchain, crewai-tools, crewai
#   Attempting uninstall: jiter
#     Found existing installation: jiter 0.8.2
#     Uninstalling jiter-0.8.2:
#       Successfully uninstalled jiter-0.8.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.57.4
#     Uninstalling openai-1.57.4:
#       Successfully uninstalled openai-1.57.4
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.2.3
#     Uninstalling langsmith-0.2.3:
#       Successfully uninstalled langsmith-0.2.3
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.25
#     Uninstalling langchain-core-0.3.25:
#       Successfully uninstalled langchain-core-0.3.25
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.12
#     Uninstalling langchain-0.3.12:
#       Successfully uninstalled langchain-0.3.12
# Successfully installed Mako-1.3.8 MarkupSafe-3.0.2 Pillow-11.0.0 alembic-1.14.0 appdirs-1.4.4 asgiref-3.8.1 auth0-python-4.7.2 backoff-2.2.1 bcrypt-4.2.1 beautifulsoup4-4.12.3 build-1.2.2.post1 cffi-1.17.1 chroma-hnswlib-0.7.6 chromadb-0.5.23 click-8.1.7 cohere-5.13.4 coloredlogs-15.0.1 crewai-0.86.0 crewai-tools-0.17.0 cryptography-43.0.3 dataclasses-json-0.6.7 deprecated-1.2.15 deprecation-2.1.0 docker-7.1.0 docstring-parser-0.16 docx2txt-0.8 durationpy-0.9 embedchain-0.1.125 et-xmlfile-2.0.0 fastapi-0.115.6 fastavro-1.10.0 filelock-3.16.1 flatbuffers-24.3.25 fsspec-2024.12.0 google-cloud-aiplatform-1.75.0 google-cloud-bigquery-3.27.0 google-cloud-core-2.4.1 google-cloud-resource-manager-1.14.0 google-cloud-storage-2.19.0 google-crc32c-1.6.0 google-resumable-media-2.7.2 gptcache-0.1.44 grpc-google-iam-v1-0.13.1 grpcio-tools-1.68.1 h2-4.1.0 hpack-4.0.0 httptools-0.6.4 httpx-0.27.2 httpx-sse-0.4.0 huggingface-hub-0.27.0 humanfriendly-10.0 hyperframe-6.0.1 importlib-metadata-8.5.0 importlib-resources-6.4.5 iniconfig-2.0.0 instructor-1.7.0 jinja2-3.1.4 jiter-0.6.1 json-repair-0.32.0 jsonpickle-4.0.1 jsonref-1.1.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 kubernetes-31.0.0 lancedb-0.17.0 langchain-0.3.13 langchain-cohere-0.3.4 langchain-community-0.3.13 langchain-core-0.3.28 langchain-experimental-0.3.3 langchain-openai-0.2.14 langsmith-0.1.147 litellm-1.55.7 markdown-it-py-3.0.0 marshmallow-3.23.2 mdurl-0.1.2 mem0ai-0.1.36 mmh3-5.0.1 monotonic-1.6 mpmath-1.3.0 mypy-extensions-1.0.0 networkx-3.4.2 nodeenv-1.9.1 oauthlib-3.2.2 onnxruntime-1.20.1 openai-1.58.1 openpyxl-3.1.5 opentelemetry-api-1.29.0 opentelemetry-exporter-otlp-proto-common-1.29.0 opentelemetry-exporter-otlp-proto-grpc-1.29.0 opentelemetry-exporter-otlp-proto-http-1.29.0 opentelemetry-instrumentation-0.50b0 opentelemetry-instrumentation-asgi-0.50b0 opentelemetry-instrumentation-fastapi-0.50b0 opentelemetry-proto-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 opentelemetry-util-http-0.50b0 outcome-1.3.0.post0 overrides-7.7.0 pandas-2.2.3 parameterized-0.9.0 pdfminer.six-20231228 pdfplumber-0.11.4 pluggy-1.5.0 portalocker-2.10.1 posthog-3.7.4 pyarrow-18.1.0 pycparser-2.22 pydantic-settings-2.7.0 pyjwt-2.10.1 pylance-0.20.0 pypdf-5.1.0 pypdfium2-4.30.1 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 pyright-1.1.391 pysbd-0.3.4 pysocks-1.7.1 pytest-8.3.4 pytube-15.0.0 pytz-2024.2 pyvis-0.3.2 qdrant-client-1.12.1 referencing-0.35.1 regex-2024.11.6 requests-oauthlib-2.0.0 rich-13.9.4 rpds-py-0.22.3 schema-0.7.7 selenium-4.27.1 setuptools-75.6.0 shapely-2.0.6 shellingham-1.5.4 sortedcontainers-2.4.0 soupsieve-2.6 starlette-0.41.3 sympy-1.13.3 tabulate-0.9.0 tiktoken-0.7.0 tokenizers-0.20.3 tomli-2.2.1 tomli-w-1.1.0 trio-0.27.0 trio-websocket-0.11.1 typer-0.15.1 types-requests-2.32.0.20241016 typing-inspect-0.9.0 tzdata-2024.2 uv-0.5.11 uvicorn-0.34.0 watchfiles-1.0.3 websocket-client-1.8.0 websockets-14.1 wrapt-1.17.0 wsproto-1.2.0 zipp-3.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade crewai crewai-tools
# Out:
# Requirement already satisfied: crewai in c:\python312\lib\site-packages (0.86.0)
# Requirement already satisfied: crewai-tools in c:\python312\lib\site-packages (0.17.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\python312\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\python312\lib\site-packages (from crewai) (4.7.2)
# Requirement already satisfied: chromadb>=0.5.18 in c:\python312\lib\site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in c:\python312\lib\site-packages (from crewai) (8.1.7)
# Requirement already satisfied: instructor>=1.3.3 in c:\python312\lib\site-packages (from crewai) (1.7.0)
# Requirement already satisfied: json-repair>=0.25.2 in c:\python312\lib\site-packages (from crewai) (0.32.0)
# Requirement already satisfied: jsonref>=1.1.0 in c:\python312\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in c:\python312\lib\site-packages (from crewai) (1.55.7)
# Requirement already satisfied: openai>=1.13.3 in c:\python312\lib\site-packages (from crewai) (1.58.1)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\python312\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in c:\python312\lib\site-packages (from crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in c:\python312\lib\site-packages (from crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in c:\python312\lib\site-packages (from crewai) (1.29.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\python312\lib\site-packages (from crewai) (0.11.4)
# Requirement already satisfied: pydantic>=2.4.2 in c:\python312\lib\site-packages (from crewai) (2.10.3)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\python312\lib\site-packages (from crewai) (1.0.1)
# Requirement already satisfied: pyvis>=0.3.2 in c:\python312\lib\site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\python312\lib\site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\python312\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli>=2.0.2 in c:\python312\lib\site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in c:\python312\lib\site-packages (from crewai) (0.5.11)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in c:\python312\lib\site-packages (from crewai-tools) (4.12.3)
# Requirement already satisfied: docker>=7.1.0 in c:\python312\lib\site-packages (from crewai-tools) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in c:\python312\lib\site-packages (from crewai-tools) (0.8)
# Requirement already satisfied: embedchain>=0.1.114 in c:\python312\lib\site-packages (from crewai-tools) (0.1.125)
# Requirement already satisfied: lancedb>=0.5.4 in c:\python312\lib\site-packages (from crewai-tools) (0.17.0)
# Requirement already satisfied: pyright>=1.1.350 in c:\python312\lib\site-packages (from crewai-tools) (1.1.391)
# Requirement already satisfied: pytest>=8.0.0 in c:\python312\lib\site-packages (from crewai-tools) (8.3.4)
# Requirement already satisfied: pytube>=15.0.0 in c:\python312\lib\site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in c:\python312\lib\site-packages (from crewai-tools) (2.32.3)
# Requirement already satisfied: selenium>=4.18.1 in c:\python312\lib\site-packages (from crewai-tools) (4.27.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.5 in c:\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (3.11.10)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in c:\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in c:\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in c:\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.2.3)
# Requirement already satisfied: soupsieve>1.2 in c:\python312\lib\site-packages (from beautifulsoup4>=4.12.3->crewai-tools) (2.6)
# Requirement already satisfied: build>=1.0.3 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (2.2.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\python312\lib\site-packages (from chromadb>=0.5.18->crewai) (13.9.4)
# Requirement already satisfied: colorama in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from click>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: pywin32>=304 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from docker>=7.1.0->crewai-tools) (308)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (1.14.0)
# Requirement already satisfied: cohere<6.0,>=5.3 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (5.13.4)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (1.75.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.44)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.13)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.13)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.2.14)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.147)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.29 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.36)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (5.1.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (2.0.36)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in c:\python312\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.7.0)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in c:\python312\lib\site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\python312\lib\site-packages (from instructor>=1.3.3->crewai) (3.1.4)
# Requirement already satisfied: jiter<0.7,>=0.6.1 in c:\python312\lib\site-packages (from instructor>=1.3.3->crewai) (0.6.1)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\python312\lib\site-packages (from instructor>=1.3.3->crewai) (2.27.1)
# Requirement already satisfied: deprecation in c:\python312\lib\site-packages (from lancedb>=0.5.4->crewai-tools) (2.1.0)
# Requirement already satisfied: pylance==0.20.0 in c:\python312\lib\site-packages (from lancedb>=0.5.4->crewai-tools) (0.20.0)
# Requirement already satisfied: packaging in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from lancedb>=0.5.4->crewai-tools) (24.2)
# Requirement already satisfied: pyarrow>=14 in c:\python312\lib\site-packages (from pylance==0.20.0->lancedb>=0.5.4->crewai-tools) (18.1.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\python312\lib\site-packages (from litellm>=1.44.22->crewai) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\python312\lib\site-packages (from litellm>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\python312\lib\site-packages (from openai>=1.13.3->crewai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\python312\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in c:\python312\lib\site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in c:\python312\lib\site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\python312\lib\site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\python312\lib\site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.29.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\python312\lib\site-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.50b0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\python312\lib\site-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\python312\lib\site-packages (from pdfplumber>=0.11.4->crewai) (11.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\python312\lib\site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python312\lib\site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: nodeenv>=1.6.0 in c:\python312\lib\site-packages (from pyright>=1.1.350->crewai-tools) (1.9.1)
# Requirement already satisfied: iniconfig in c:\python312\lib\site-packages (from pytest>=8.0.0->crewai-tools) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\python312\lib\site-packages (from pytest>=8.0.0->crewai-tools) (1.5.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from pyvis>=0.3.2->crewai) (8.30.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\python312\lib\site-packages (from pyvis>=0.3.2->crewai) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in c:\python312\lib\site-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests>=2.31.0->crewai-tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests>=2.31.0->crewai-tools) (2024.12.14)
# Requirement already satisfied: trio~=0.17 in c:\python312\lib\site-packages (from selenium>=4.18.1->crewai-tools) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\python312\lib\site-packages (from selenium>=4.18.1->crewai-tools) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in c:\python312\lib\site-packages (from selenium>=4.18.1->crewai-tools) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.18.3)
# Requirement already satisfied: Mako in c:\python312\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools) (1.3.8)
# Requirement already satisfied: pyproject_hooks in c:\python312\lib\site-packages (from build>=1.0.3->chromadb>=0.5.18->crewai) (1.2.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\python312\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\python312\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in c:\python312\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\python312\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (2.32.0.20241016)
# Requirement already satisfied: cffi>=1.12 in c:\python312\lib\site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\python312\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\python312\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.18->crewai) (0.41.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.24.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.37.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (3.27.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.0.6)
# Requirement already satisfied: cachetools in c:\python312\lib\site-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools) (5.5.0)
# Requirement already satisfied: httpcore==1.* in c:\python312\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.18->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.18->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\python312\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai) (3.21.0)
# Requirement already satisfied: decorator in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib in c:\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (0.9)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in c:\python312\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\python312\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.3)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in c:\python312\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.3.3)
# Requirement already satisfied: pandas>=1.4.3 in c:\python312\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\python312\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\python312\lib\site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\python312\lib\site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (2.7.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in c:\python312\lib\site-packages (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in c:\python312\lib\site-packages (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (1.12.1)
# Requirement already satisfied: coloredlogs in c:\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (24.3.25)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in c:\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in c:\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in c:\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: asgiref~=3.0 in c:\python312\lib\site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\python312\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.18->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\python312\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.18->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python312\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.18->crewai) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python312\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\python312\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai) (0.27.0)
# Requirement already satisfied: sortedcontainers in c:\python312\lib\site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools) (2.4.0)
# Requirement already satisfied: outcome in c:\python312\lib\site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in c:\python312\lib\site-packages (from trio-websocket~=0.9->selenium>=4.18.1->crewai-tools) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\python312\lib\site-packages (from typer>=0.9.0->chromadb>=0.5.18->crewai) (1.5.4)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai-tools) (1.7.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in c:\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (14.1)
# Requirement already satisfied: pycparser in c:\python312\lib\site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.23.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.68.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\python312\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\python312\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\python312\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\python312\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\python312\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.6.0)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai) (2024.12.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.26->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.33)
# Requirement already satisfied: mdurl~=0.1 in c:\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.18->crewai) (0.1.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2024.2)
# Requirement already satisfied: wcwidth in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\python312\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (1.68.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\python312\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (2.10.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\python312\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\safdaralishah\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (1.3.0)
# Requirement already satisfied: setuptools in c:\python312\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (75.6.0)
# Requirement already satisfied: h2<5,>=3 in c:\python312\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (4.1.0)
# Requirement already satisfied: pyreadline3 in c:\python312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (3.5.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.6.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\python312\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\python312\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install dotenv
# Out:
# Collecting dotenvNote: you may need to restart the kernel to use updated packages.
#
#   Using cached dotenv-0.0.5.tar.gz (2.4 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install backend dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [29 lines of output]
#       Collecting distribute
#         Using cached distribute-0.7.3.zip (145 kB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         Ã— Preparing metadata (pyproject.toml) did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [6 lines of output]
#             usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#                or: setup.py --help [cmd1 cmd2 ...]
#                or: setup.py --help-commands
#                or: setup.py cmd --help
#
#             error: invalid command 'dist_info'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       Ã— Encountered error while generating package metadata.
#       â•°â”€> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install backend dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import os, dotenv
from dotenv import load_dotenv
load_dotenv()
gemini_api_key = os.getenv("GEMINI_API_KEY")
print(gemini_api_key)
# Out:
# AIzaSyCeYayQ7WgP1B1Rn_zrz6WrmuamI72JC_o

# %%
from crewai import Agent, Task, Crew, LLM
